# %%
import sys
from sklearn.metrics.pairwise import euclidean_distances
import pandas as pd
import numpy as np
import plotly

# %%
sys.path.append('/Users/gracer/Google Drive/ABCD/ABCD_puberty/scripts/puberty_nets/')

# %%
from puberty_nets import helpers

# %%
GRAPHS = helpers.dilly_of_a_pickle('/Users/gracer/Google Drive/ABCD/ABCD_puberty/_data/current')

# %%
list(GRAPHS['CC'].values())[0]
# Out:
# array([0.69981717, 0.72516779, 0.74568017, 0.71287599, 0.68655947,
#        0.66633442, 0.64182013, 0.71467764, 0.65227069, 0.59278667,
#        0.70639928, 0.71492046, 0.69711195, 0.71156379, 0.67076624,
#        0.66362908, 0.67154016, 0.71921679, 0.6729196 , 0.65496179,
#        0.72753169, 0.70164805, 0.70810387, 0.6837844 , 0.64477429,
#        0.65603959, 0.67914671, 0.70496268, 0.68430932, 0.71698767,
#        0.71038381, 0.7110094 , 0.70001292, 0.71941091, 0.62983498,
#        0.70923   , 0.72528854, 0.65418063, 0.71758598, 0.7251351 ,
#        0.72502085, 0.69697906, 0.7179459 , 0.71088036, 0.71507313,
#        0.72130076, 0.72034685, 0.72927743, 0.70104499, 0.74577226,
#        0.67766839, 0.70515382, 0.72797349, 0.692481  , 0.73494116,
#        0.72829515, 0.71653368, 0.71892663, 0.67064514, 0.68798129,
#        0.73077531, 0.74390576, 0.72066493, 0.65579225, 0.63147922,
#        0.76285551, 0.65210875, 0.72723129, 0.70757488, 0.69076845,
# ...

# %%
list(GRAPHS['mean_FC'].values())[100]
# Out:
# [0.8547148797061523]

# %%
labels = pd.read_csv('/Users/gracer/Google Drive/ABCD/important_txt/locations.csv', sep=",")

# %%
PCdf = pd.DataFrame(data = GRAPHS['PC'].values(), index = GRAPHS['PC'].keys(), columns = labels)

# %%
CCdf = pd.DataFrame(data = GRAPHS['CC'].values(), index = GRAPHS['CC'].keys(), columns = labels)

# %%
CCdf
# Out:
#                      (-7, -52, 61, Precuneus)  \
# sub-NDARINVMFVA1BZF                  0.699817
# sub-NDARINVD9L81NY5                  0.290602
# sub-NDARINV8PHEF3UH                  0.468990
# sub-NDARINV08FUB58A                  0.266630
# sub-NDARINV8JTY86NW                  0.706628
# sub-NDARINV1MKWVMP1                  0.257234
# sub-NDARINVK1GY1F0R                  0.299902
# sub-NDARINV4878W3DV                  0.591996
# sub-NDARINVJZP468AD                  0.822348
# sub-NDARINV56YBTJHF                  0.832786
# sub-NDARINV2NVERUP6                  0.203930
# sub-NDARINVKJKYNK5V                  0.252233
# sub-NDARINV1Y1Z29D0                  0.489936
# sub-NDARINVKTZGA2UH                  0.312583
# sub-NDARINVH6K9F426                  0.728128
# sub-NDARINVK8CYP94F                  0.661900
# sub-NDARINV45HV5L52                  0.195540
# sub-NDARINV72MV78KG                  0.797072
# sub-NDARINVMA0MXL96                  0.137606
# ...

# %%
SEXdf = pd.DataFrame(data = GRAPHS['sex'].values(), index = GRAPHS['sex'].keys(), columns = ['sex'])

# %%
PCSdf = pd.DataFrame(data = GRAPHS['PCS'].values(), index = GRAPHS['PCS'].keys(), columns = ['PCS'])

# %%
OVOBdf = pd.DataFrame(data = GRAPHS['OVOB'].values(), index = GRAPHS['OVOB'].keys(), columns = ['OVOB'])

# %%
FCdf = pd.DataFrame(data = GRAPHS['mean_FC'].values(), index = GRAPHS['mean_FC'].keys(), columns = ['mean_FC'])

# %%
totalDF=pd.concat([PCdf, CCdf, SEXdf, PCSdf, OVOBdf, FCdf], axis=1)
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
totalDF
# Out:
#                      (-7, -52, 61, Precuneus)  \
# sub-NDARINV019DXLU4                       NaN
# sub-NDARINV030W95VP                       NaN
# sub-NDARINV08FUB58A                  0.497601
# sub-NDARINV0A4ZDYNL                  0.564246
# sub-NDARINV0CKA3YZX                  0.490797
# sub-NDARINV0FUC15ZB                  0.486572
# sub-NDARINV0HXXANFJ                  0.653672
# sub-NDARINV0L7XB3AW                  0.472310
# sub-NDARINV0MCARYLD                       NaN
# sub-NDARINV0NR55WME                  0.504005
# sub-NDARINV0VBJ9TP2                  0.410559
# sub-NDARINV0W00RU2X                       NaN
# sub-NDARINV0X02CUCY                  0.440797
# sub-NDARINV10ZLTFJZ                  0.449099
# sub-NDARINV1ET4JE3B                       NaN
# sub-NDARINV1JXDFV9Z                       NaN
# sub-NDARINV1MKWVMP1                  0.499928
# sub-NDARINV1NJK6BVY                  0.635853
# sub-NDARINV1NZMD6UK                  0.499901
# ...

# %%
meanPC={}
for key, values in GRAPHS['PC'].items():
    meanPC[key]=values.mean()
    
PCmeandf = pd.DataFrame(data = meanPC.values(), index = meanPC.keys(), columns = ['meanPC'])

# %%
meanCC={}
for key, values in GRAPHS['CC'].items():
    meanCC[key]=values.mean()
CCmeandf = pd.DataFrame(data = meanCC.values(), index = meanCC.keys(), columns = ['meanCC'])

# %%
totalDF=pd.concat([totalDF, PCmeandf, CCmeandf], axis=1)
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
totalDF
# Out:
#                      (-7, -52, 61, Precuneus)  \
# sub-NDARINV019DXLU4                       NaN
# sub-NDARINV030W95VP                       NaN
# sub-NDARINV08FUB58A                  0.497601
# sub-NDARINV0A4ZDYNL                  0.564246
# sub-NDARINV0CKA3YZX                  0.490797
# sub-NDARINV0FUC15ZB                  0.486572
# sub-NDARINV0HXXANFJ                  0.653672
# sub-NDARINV0L7XB3AW                  0.472310
# sub-NDARINV0MCARYLD                       NaN
# sub-NDARINV0NR55WME                  0.504005
# sub-NDARINV0VBJ9TP2                  0.410559
# sub-NDARINV0W00RU2X                       NaN
# sub-NDARINV0X02CUCY                  0.440797
# sub-NDARINV10ZLTFJZ                  0.449099
# sub-NDARINV1ET4JE3B                       NaN
# sub-NDARINV1JXDFV9Z                       NaN
# sub-NDARINV1MKWVMP1                  0.499928
# sub-NDARINV1NJK6BVY                  0.635853
# sub-NDARINV1NZMD6UK                  0.499901
# ...

# %%
interest =  pd.read_csv('/Users/gracer/Google Drive/ABCD/ABCD_puberty/_data/data4analysis2.txt', sep=" ", header=None, 
                 index_col=False)
interest.set_index([0], inplace=True)

# %%
interest.columns = ['sex', 'PCS', 'OVOB','BMItile','PDScore','age']

# %%
totalDF=pd.concat([totalDF, interest], axis=1)
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
totalDF
# Out:
#                      (-7, -52, 61, Precuneus)  \
# sub-NDARINV007W6H7B                       NaN
# sub-NDARINV00CY2MDM                       NaN
# sub-NDARINV00LJVZK2                       NaN
# sub-NDARINV00NPMHND                       NaN
# sub-NDARINV00X2TBWJ                       NaN
# sub-NDARINV014RTM1V                       NaN
# sub-NDARINV019DXLU4                       NaN
# sub-NDARINV01EN91PG                       NaN
# sub-NDARINV01NAYMZH                       NaN
# sub-NDARINV028D3ELL                       NaN
# sub-NDARINV02EBX0JJ                       NaN
# sub-NDARINV02H7G2T6                       NaN
# sub-NDARINV02RCED7D                       NaN
# sub-NDARINV030W95VP                       NaN
# sub-NDARINV03BDCNWM                       NaN
# sub-NDARINV03NW0RKL                       NaN
# sub-NDARINV05CA3VX5                       NaN
# sub-NDARINV05T64PXD                       NaN
# sub-NDARINV05WK8AN7                       NaN
# ...

# %%
plotly.tools.set_credentials_file(username='Grace.Shearrer', api_key='IcYgvOhSgT0bDwj9T7FG')

# %%
import string
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go

        
data = []

# for col in totalDF.columns:
#     print(col[-1])
#     print(CCdf[col])

data.append(go.Box( y=totalDF['mean_FC'],x = totalDF['OVOB'], name='mean CLustering Coeffiecent', showlegend=False ) )

# data.append(go.Scatter( x = totalDF['PCS'], y = totalDF['mean_FC'], mode='lines', name='mean' ) )

# IPython notebook
py.iplot(data, filename='pandas-box-plot')

# url = py.plot(data, filename='pandas-box-plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~grace.shearrer/41.embed" height="525px" width="100%"></iframe>

# %%
from scipy import stats
data=[]
slope, intercept, r_value, p_value, std_err = stats.linregress(totalDF['age'],totalDF['meanCC'])
line = slope*totalDF['age']+intercept

# Create a trace
trace = go.Scatter(
    x = totalDF['age'],
    y = totalDF['meanCC'],
    mode = 'markers'
)

trace2 = go.Scatter(
                  x = totalDF['age'],
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='Fit'
                  )

layout = go.Layout(
                title='Linear Fit in Python',
                plot_bgcolor='rgb(229, 229, 229)',
                  xaxis=go.XAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  yaxis=go.YAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)')
                )

data = [trace1, trace2]
fig = go.Figure(data=data, layout=layout)

py.plot(fig, filename='Linear-Fit-in-python')
# or plot with: plot_url = py.plot(data, filename='basic-line')
# Out:
# /Users/gracer/.local/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:426: DeprecationWarning:
#
# plotly.graph_objs.Marker is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Marker
#   - plotly.graph_objs.histogram.selected.Marker
#   - etc.
#
#
# /Users/gracer/.local/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:531: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# /Users/gracer/.local/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
# 'https://plot.ly/~grace.shearrer/43'

# %%
finalDF = totalDF[pd.notnull(totalDF['mean_FC'])]

# %%
finalDF.to_csv('/Users/gracer/Google Drive/ABCD/ABCD_puberty/_data/graph_data.csv', sep=',')

# %% [markdown]
# ## Within network changes
# All within network pairwise relationships were averaged per group. Two-tailed T-test to assess differences. Bonferroni corrections as needed.

# %% [markdown]
# ## Between network changes
# Average connectivity is calculated per network. Compare the between network interactions.

# %% [markdown]
# ## Connectivity Strength
# Caluclate Euclidean distance for each ROI-ROI pair. Linear regression with distance as a predictor of connectivity strength between groups.
# sklearn.metrics.pairwise.euclidean_distances(X, Y=None, Y_norm_squared=None, squared=False, X_norm_squared=None)
